# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
overal_results = np.load('overal_results.npy',allow_pickle='TRUE').item()

# %%
overal_results.keys()
# Out:
# dict_keys(['Cora', 'CiteSeer', 'PubMed'])

# %%
overal_results['Cora'].keys()
# Out:
# dict_keys(['SGC', 'GCN', 'GAT', 'residualConv'])

# %%
overal_results['Cora']['GCN'].keys()
# Out:
# dict_keys(['relu', 'leakyRelu', 'tanh', 'sigmoid'])

# %%
overal_results['Cora']['GCN']['relu'].keys()
# Out:
# dict_keys(['glorot', 'uniform', 'kaiming_uniform', None])

# %%
overal_results['Cora']['GCN']['relu']['glorot'].keys()
# Out:
# dict_keys([0.1, 0.3, 0.5, 0.7, 0.9])

# %%
#example
overal_results['Cora']['GCN']['relu']['glorot'][0.3]
# Out:
# [0.317,
#  0.524,
#  0.628,
#  0.669,
#  0.683,
#  0.709,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.735,
#  0.723,
#  0.723,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.757,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
#  0.742,
# ...

# %% [markdown]
# ### Activation Function Analysis
# In simple datasers like cora, there is no big difference. But as dataset gets more complicated, relu and leaky relu show more better results.

# %%
relu_Cora = overal_results['Cora']['GAT']['relu'][None][0.1]
leakyRelu_Cora = overal_results['Cora']['GAT']['leakyRelu'][None][0.1]
tanh_Cora = overal_results['Cora']['GAT']['tanh'][None][0.1]
sigmoid_Cora = overal_results['Cora']['GAT']['sigmoid'][None][0.1]

relu_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.1]
leakyRelu_CiteSeer = overal_results['CiteSeer']['GAT']['leakyRelu'][None][0.1]
tanh_CiteSeer = overal_results['CiteSeer']['GAT']['tanh'][None][0.1]
sigmoid_CiteSeer = overal_results['CiteSeer']['GAT']['sigmoid'][None][0.1]

relu_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.1]
leakyRelu_PubMed = overal_results['PubMed']['GAT']['leakyRelu'][None][0.1]
tanh_PubMed = overal_results['PubMed']['GAT']['tanh'][None][0.1]
sigmoid_PubMed = overal_results['PubMed']['GAT']['sigmoid'][None][0.1]

fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20,7))
st = fig.suptitle("Activation Fnction Comparison  (GAT Layer)", fontsize="x-large")
# Plot the distributions and label each Axes
axes[0].plot(relu_Cora, label='Relu',linewidth = 3)
axes[0].plot(leakyRelu_Cora, label='Leaky Relu', linestyle = 'dashed', linewidth = 3)
axes[0].plot(tanh_Cora, label='Tanh',linestyle = '-.', linewidth = 3)
axes[0].plot(sigmoid_Cora, label='Sigmoid',linestyle = 'dotted', linewidth = 3)
axes[0].set_title("Cora Dataset", fontsize = 18)
axes[0].set_ylim([0.3, 0.85])
axes[0].tick_params(axis='x', labelsize = 18)
axes[0].tick_params(axis='y', labelsize = 18)
axes[0].set_ylabel('Accuracy', fontsize = 18)

axes[1].plot(relu_CiteSeer, label='Relu', linewidth = 3)
axes[1].plot(leakyRelu_CiteSeer, label='Leaky Relu',linestyle = 'dashed', linewidth = 3)
axes[1].plot(tanh_CiteSeer, label='Tanh',linestyle = '-.', linewidth = 3)
axes[1].plot(sigmoid_CiteSeer, label='Sigmoid',linestyle = 'dotted', linewidth = 3)
axes[1].set_title("CiteSeer Dataset", fontsize = 20)
axes[1].set_ylim([0.3, 0.85])
axes[1].tick_params(axis='x', labelsize = 18)
axes[1].tick_params(axis='y', labelsize = 18)
axes[1].set_xlabel('Epochs', fontsize = 18)

axes[2].plot(relu_PubMed, label='Relu', linewidth = 3)
axes[2].plot(leakyRelu_PubMed, label='Leaky Relu',linestyle = 'dashed', linewidth = 3)
axes[2].plot(tanh_PubMed, label='Tanh',linestyle = '-.', linewidth = 3)
axes[2].plot(sigmoid_PubMed, label='Sigmoid',linestyle = 'dotted', linewidth = 3)
axes[2].set_title("PubMed Dataset", fontsize = 18)
axes[2].set_ylim([0.3, 0.85])
axes[2].tick_params(axis='x', labelsize = 18)
axes[2].tick_params(axis='y', labelsize = 18)
# Add a legend to each Axes with default values
for ax in axes:
    ax.legend(loc="lower right")

plt.tight_layout()
#plt.savefig('./OUTPUT/ActivationFunctionResidualConv.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
overal_results['Cora'].keys()
# Out:
# dict_keys(['SGC', 'GCN', 'GAT', 'residualConv'])

# %%
GCN_relu_Cora = overal_results['Cora']['GCN']['relu'][None][0.1]
SGC_relu_Cora = overal_results['Cora']['SGC']['relu'][None][0.1]
GAT_relu_Cora = overal_results['Cora']['GAT']['relu'][None][0.1]
Res_relu_Cora = overal_results['Cora']['residualConv']['relu'][None][0.1]

GCN_leakyRelu_Cora = overal_results['Cora']['GCN']['leakyRelu'][None][0.1]
SGC_leakyRelu_Cora = overal_results['Cora']['SGC']['leakyRelu'][None][0.1]
GAT_leakyRelu_Cora = overal_results['Cora']['GAT']['leakyRelu'][None][0.1]
Res_leakyRelu_Cora = overal_results['Cora']['residualConv']['leakyRelu'][None][0.1]

GCN_tanh_Cora = overal_results['Cora']['GCN']['tanh'][None][0.1]
SGC_tanh_Cora = overal_results['Cora']['SGC']['tanh'][None][0.1]
GAT_tanh_Cora = overal_results['Cora']['GAT']['tanh'][None][0.1]
Res_tanh_Cora = overal_results['Cora']['residualConv']['tanh'][None][0.1]

GCN_sigmoid_Cora = overal_results['Cora']['GCN']['sigmoid'][None][0.1]
SGC_sigmoid_Cora = overal_results['Cora']['SGC']['sigmoid'][None][0.1]
GAT_sigmoid_Cora = overal_results['Cora']['GAT']['sigmoid'][None][0.1]
Res_sigmoid_Cora = overal_results['Cora']['residualConv']['sigmoid'][None][0.1]

GCN_relu_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.1]
SGC_relu_CiteSeer = overal_results['CiteSeer']['SGC']['relu'][None][0.1]
GAT_relu_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.1]
Res_relu_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.1]

GCN_leakyRelu_CiteSeer = overal_results['CiteSeer']['GCN']['leakyRelu'][None][0.1]
SGC_leakyRelu_CiteSeer = overal_results['CiteSeer']['SGC']['leakyRelu'][None][0.1]
GAT_leakyRelu_CiteSeer = overal_results['CiteSeer']['GAT']['leakyRelu'][None][0.1]
Res_leakyRelu_CiteSeer = overal_results['CiteSeer']['residualConv']['leakyRelu'][None][0.1]

GCN_tanh_CiteSeer = overal_results['CiteSeer']['GCN']['tanh'][None][0.1]
SGC_tanh_CiteSeer = overal_results['CiteSeer']['SGC']['tanh'][None][0.1]
GAT_tanh_CiteSeer = overal_results['CiteSeer']['GAT']['tanh'][None][0.1]
Res_tanh_CiteSeer = overal_results['CiteSeer']['residualConv']['tanh'][None][0.1]

GCN_sigmoid_CiteSeer = overal_results['CiteSeer']['GCN']['sigmoid'][None][0.1]
SGC_sigmoid_CiteSeer = overal_results['CiteSeer']['SGC']['sigmoid'][None][0.1]
GAT_sigmoid_CiteSeer = overal_results['CiteSeer']['GAT']['sigmoid'][None][0.1]
Res_sigmoid_CiteSeer = overal_results['CiteSeer']['residualConv']['sigmoid'][None][0.1]

GCN_relu_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.1]
SGC_relu_PubMed = overal_results['PubMed']['SGC']['relu'][None][0.1]
GAT_relu_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.1]
Res_relu_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.1]

GCN_leakyRelu_PubMed = overal_results['PubMed']['GCN']['leakyRelu'][None][0.1]
SGC_leakyRelu_PubMed = overal_results['PubMed']['SGC']['leakyRelu'][None][0.1]
GAT_leakyRelu_PubMed = overal_results['PubMed']['GAT']['leakyRelu'][None][0.1]
Res_leakyRelu_PubMed = overal_results['PubMed']['residualConv']['leakyRelu'][None][0.1]

GCN_tanh_PubMed = overal_results['PubMed']['GCN']['tanh'][None][0.1]
SGC_tanh_PubMed = overal_results['PubMed']['SGC']['tanh'][None][0.1]
GAT_tanh_PubMed = overal_results['PubMed']['GAT']['tanh'][None][0.1]
Res_tanh_PubMed = overal_results['PubMed']['residualConv']['tanh'][None][0.1]

GCN_sigmoid_PubMed = overal_results['PubMed']['GCN']['sigmoid'][None][0.1]
SGC_sigmoid_PubMed = overal_results['PubMed']['SGC']['sigmoid'][None][0.1]
GAT_sigmoid_PubMed = overal_results['PubMed']['GAT']['sigmoid'][None][0.1]
Res_sigmoid_PubMed = overal_results['PubMed']['residualConv']['sigmoid'][None][0.1]

fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20,7))
st = fig.suptitle("Activation Fnction Comparison", fontsize="x-large")
# Plot the distributions and label each Axes
axes[0].plot(GCN_relu_Cora, label='GCN-Relu', linewidth = 2.5)
axes[0].plot(SGC_relu_Cora, label='SGC-Relu', linewidth = 2.5)
axes[0].plot(GAT_relu_Cora, label='GAT-Relu', linewidth = 2.5)
axes[0].plot(Res_relu_Cora, label='Res-Relu', linewidth = 2.5)

axes[0].plot(GCN_leakyRelu_Cora, label='GCN-Leaky Relu', linewidth = 2.5)
axes[0].plot(SGC_leakyRelu_Cora, label='SGC-Leaky Relu', linewidth = 2.5)
axes[0].plot(GAT_leakyRelu_Cora, label='GAT-Leaky Relu', linewidth = 2.5)
axes[0].plot(Res_leakyRelu_Cora, label='Res-Leaky Relu', linewidth = 2.5)

axes[0].plot(GCN_tanh_Cora, label='GCN-Relu', linewidth = 2.5)
axes[0].plot(SGC_tanh_Cora, label='SGC-Relu', linewidth = 2.5)
axes[0].plot(GAT_tanh_Cora, label='GAT-Relu', linewidth = 2.5)
axes[0].plot(Res_tanh_Cora, label='Res-Relu', linewidth = 2.5)

axes[0].plot(GCN_sigmoid_Cora, label='GCN-Relu', linewidth = 2.5)
axes[0].plot(SGC_sigmoid_Cora, label='SGC-Relu', linewidth = 2.5)
axes[0].plot(GAT_sigmoid_Cora, label='GAT-Relu', linewidth = 2.5)
axes[0].plot(Res_sigmoid_Cora, label='Res-Relu', linewidth = 2.5)

axes[0].set_title("Cora Dataset", fontsize = 18)
axes[0].tick_params(axis='x', labelsize = 18)
axes[0].tick_params(axis='y', labelsize = 18)
axes[0].set_ylabel('Accuracy', fontsize = 18)

axes[1].plot(GCN_relu_CiteSeer, label='GCN-Relu', linewidth = 2.5)
axes[1].plot(SGC_relu_CiteSeer, label='SGC-Relu', linewidth = 2.5)
axes[1].plot(GAT_relu_CiteSeer, label='GAT-Relu', linewidth = 2.5)
axes[1].plot(Res_relu_CiteSeer, label='Res-Relu', linewidth = 2.5)

axes[1].plot(GCN_leakyRelu_CiteSeer, label='GCN-Leaky Relu', linewidth = 2.5)
axes[1].plot(SGC_leakyRelu_CiteSeer, label='SGC-Leaky Relu', linewidth = 2.5)
axes[1].plot(GAT_leakyRelu_CiteSeer, label='GAT-Leaky Relu', linewidth = 2.5)
axes[1].plot(Res_leakyRelu_CiteSeer, label='Res-Leaky Relu', linewidth = 2.5)


axes[1].plot(GCN_tanh_CiteSeer, label='GCN-Relu', linewidth = 2.5)
axes[1].plot(SGC_tanh_CiteSeer, label='SGC-Relu', linewidth = 2.5)
axes[1].plot(GAT_tanh_CiteSeer, label='GAT-Relu', linewidth = 2.5)
axes[1].plot(Res_tanh_CiteSeer, label='Res-Relu', linewidth = 2.5)

axes[1].plot(GCN_sigmoid_CiteSeer, label='GCN-Relu', linewidth = 2.5)
axes[1].plot(SGC_sigmoid_CiteSeer, label='SGC-Relu', linewidth = 2.5)
axes[1].plot(GAT_sigmoid_CiteSeer, label='GAT-Relu', linewidth = 2.5)
axes[1].plot(Res_sigmoid_CiteSeer, label='Res-Relu', linewidth = 2.5)

axes[1].set_title("CiteSeer Dataset", fontsize = 18)
axes[1].tick_params(axis='x', labelsize = 18)
axes[1].tick_params(axis='y', labelsize = 18)
axes[1].set_xlabel('Epochs', fontsize = 18)

axes[2].plot(GCN_relu_PubMed, label='GCN-Relu', linewidth = 2.5)
axes[2].plot(SGC_relu_PubMed, label='SGC-Relu', linewidth = 2.5)
axes[2].plot(GAT_relu_PubMed, label='GAT-Relu', linewidth = 2.5)
axes[2].plot(Res_relu_PubMed, label='Res-Relu', linewidth = 2.5)

axes[2].plot(GCN_leakyRelu_PubMed, label='GCN-Leaky Relu', linewidth = 2.5)
axes[2].plot(SGC_leakyRelu_PubMed, label='SGC-Leaky Relu', linewidth = 2.5)
axes[2].plot(GAT_leakyRelu_PubMed, label='GAT-Leaky Relu', linewidth = 2.5)
axes[2].plot(Res_leakyRelu_PubMed, label='Res-Leaky Relu', linewidth = 2.5)

axes[2].plot(GCN_tanh_PubMed, label='GCN-Relu', linewidth = 2.5)
axes[2].plot(SGC_tanh_PubMed, label='SGC-Relu', linewidth = 2.5)
axes[2].plot(GAT_tanh_PubMed, label='GAT-Relu', linewidth = 2.5)
axes[2].plot(Res_tanh_PubMed, label='Res-Relu', linewidth = 2.5)

axes[2].plot(GCN_sigmoid_PubMed, label='GCN-Relu', linewidth = 2.5)
axes[2].plot(SGC_sigmoid_PubMed, label='SGC-Relu', linewidth = 2.5)
axes[2].plot(GAT_sigmoid_PubMed, label='GAT-Relu', linewidth = 2.5)
axes[2].plot(Res_sigmoid_PubMed, label='Res-Relu', linewidth = 2.5)
axes[2].tick_params(axis='x', labelsize = 18)
axes[2].tick_params(axis='y', labelsize = 18)

axes[2].set_title("PubMed Dataset", fontsize = 18)

# Add a legend to each Axes with default values
for ax in axes:
    ax.legend()
plt.tight_layout()
plt.savefig('AllActivationFunctions.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Initialization Analysis

# %%
random_Cora = overal_results['Cora']['GCN']['relu'][None][0.1]
uniform_Cora = overal_results['Cora']['GCN']['relu']['uniform'][0.1]
glorot_Cora = overal_results['Cora']['GCN']['relu']['glorot'][0.1]
kaiming_uniform_Cora = overal_results['Cora']['GCN']['relu']['kaiming_uniform'][0.1]

random_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.1]
uniform_CiteSeer = overal_results['CiteSeer']['GCN']['relu']['uniform'][0.1]
glorot_CiteSeer = overal_results['CiteSeer']['GCN']['relu']['glorot'][0.1]
kaiming_uniform_CiteSeer = overal_results['CiteSeer']['GCN']['relu']['kaiming_uniform'][0.1]

random_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.1]
uniform_PubMed = overal_results['PubMed']['GCN']['relu']['uniform'][0.1]
glorot_PubMed = overal_results['PubMed']['GCN']['relu']['glorot'][0.1]
kaiming_uniform_PubMed = overal_results['PubMed']['GCN']['relu']['kaiming_uniform'][0.1]

fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20,7))
st = fig.suptitle("Initialization Comparison  (GCN Layer, relu activation)", fontsize="x-large")
# Plot the distributions and label each Axes
axes[0].plot(random_Cora, label='Random', linewidth=3)
axes[0].plot(uniform_Cora, label='Uniform',linestyle = 'dashed', linewidth=3)
axes[0].plot(glorot_Cora, label='Golorot',linestyle = '-.', linewidth=3)
axes[0].plot(kaiming_uniform_Cora, label='Kaiming',linestyle = 'dotted', linewidth=3)
axes[0].set_title("Cora Dataset", fontsize = 18)
axes[0].set_ylim([0.3, 0.85])
axes[0].tick_params(axis='x', labelsize = 18)
axes[0].tick_params(axis='y', labelsize = 18)
axes[0].set_ylabel('Accuracy', fontsize = 18)

axes[1].plot(random_CiteSeer, label='Random', linewidth=3)
axes[1].plot(uniform_CiteSeer, label='Uniform',linestyle = 'dashed', linewidth=3)
axes[1].plot(glorot_CiteSeer, label='Golorot',linestyle = '-.', linewidth=3)
axes[1].plot(kaiming_uniform_CiteSeer, label='Kaiming',linestyle = 'dotted', linewidth=3)
axes[1].set_title("CiteSeer Dataset", fontsize = 18)
axes[1].set_ylim([0.3, 0.85])
axes[1].tick_params(axis='x', labelsize = 18)
axes[1].tick_params(axis='y', labelsize = 18)
axes[1].set_xlabel('Epochs', fontsize = 18)

axes[2].plot(random_PubMed, label='Random',linewidth=3)
axes[2].plot(uniform_PubMed, label='Uniform',linestyle = 'dashed',linewidth=3)
axes[2].plot(glorot_PubMed, label='Golorot',linestyle = '-.',linewidth=3)
axes[2].plot(kaiming_uniform_PubMed, label='Kaiming',linestyle = 'dotted',linewidth=3)
axes[2].set_title("PubMed Dataset", fontsize = 18)
axes[2].set_ylim([0.3, 0.85])
axes[2].tick_params(axis='x', labelsize = 18)
axes[2].tick_params(axis='y', labelsize = 18)
# Add a legend to each Axes with default values
for ax in axes:
    ax.legend(loc="lower right")
plt.tight_layout()
#plt.savefig('Initialization.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
overal_results['Cora'].keys()
# Out:
# dict_keys(['SGC', 'GCN', 'GAT', 'residualConv'])

# %%
GCN_random_Cora = overal_results['Cora']['GCN']['relu'][None][0.1]
SGC_random_Cora = overal_results['Cora']['SGC']['relu'][None][0.1]
GAT_random_Cora = overal_results['Cora']['GAT']['relu'][None][0.1]
Res_random_Cora = overal_results['Cora']['residualConv']['relu'][None][0.1]

GCN_uniform_Cora = overal_results['Cora']['GCN']['relu']['uniform'][0.1]
SGC_uniform_Cora = overal_results['Cora']['SGC']['relu']['uniform'][0.1]
GAT_uniform_Cora = overal_results['Cora']['GAT']['relu']['uniform'][0.1]
Res_uniform_Cora = overal_results['Cora']['residualConv']['relu']['uniform'][0.1]

GCN_glorot_Cora = overal_results['Cora']['GCN']['relu']['glorot'][0.1]
SGC_glorot_Cora = overal_results['Cora']['SGC']['relu']['glorot'][0.1]
GAT_glorot_Cora = overal_results['Cora']['GAT']['relu']['glorot'][0.1]
Res_glorot_Cora = overal_results['Cora']['residualConv']['relu']['glorot'][0.1]

GCN_kaiming_uniform_Cora = overal_results['Cora']['GCN']['relu']['kaiming_uniform'][0.1]
SGC_kaiming_uniform_Cora = overal_results['Cora']['SGC']['relu']['kaiming_uniform'][0.1]
GAT_kaiming_uniform_Cora = overal_results['Cora']['GAT']['relu']['kaiming_uniform'][0.1]
Res_kaiming_uniform_Cora = overal_results['Cora']['residualConv']['relu']['kaiming_uniform'][0.1]

GCN_random_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.1]
SGC_random_CiteSeer = overal_results['CiteSeer']['SGC']['relu'][None][0.1]
GAT_random_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.1]
Res_random_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.1]

GCN_uniform_CiteSeer = overal_results['CiteSeer']['GCN']['relu']['uniform'][0.1]
SGC_uniform_CiteSeer = overal_results['CiteSeer']['SGC']['relu']['uniform'][0.1]
GAT_uniform_CiteSeer = overal_results['CiteSeer']['GAT']['relu']['uniform'][0.1]
Res_uniform_CiteSeer = overal_results['CiteSeer']['residualConv']['relu']['uniform'][0.1]

GCN_glorot_CiteSeer = overal_results['CiteSeer']['GCN']['relu']['glorot'][0.1]
SGC_glorot_CiteSeer = overal_results['CiteSeer']['SGC']['relu']['glorot'][0.1]
GAT_glorot_CiteSeer = overal_results['CiteSeer']['GAT']['relu']['glorot'][0.1]
Res_glorot_CiteSeer = overal_results['CiteSeer']['residualConv']['relu']['glorot'][0.1]

GCN_kaiming_uniform_CiteSeer = overal_results['CiteSeer']['GCN']['relu']['kaiming_uniform'][0.1]
SGC_kaiming_uniform_CiteSeer = overal_results['CiteSeer']['SGC']['relu']['kaiming_uniform'][0.1]
GAT_kaiming_uniform_CiteSeer = overal_results['CiteSeer']['GAT']['relu']['kaiming_uniform'][0.1]
Res_kaiming_uniform_CiteSeer = overal_results['CiteSeer']['residualConv']['relu']['kaiming_uniform'][0.1]

GCN_random_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.1]
SGC_random_PubMed = overal_results['PubMed']['SGC']['relu'][None][0.1]
GAT_random_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.1]
Res_random_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.1]

GCN_uniform_PubMed = overal_results['PubMed']['GCN']['relu']['uniform'][0.1]
SGC_uniform_PubMed = overal_results['PubMed']['SGC']['relu']['uniform'][0.1]
GAT_uniform_PubMed = overal_results['PubMed']['GAT']['relu']['uniform'][0.1]
Res_uniform_PubMed = overal_results['PubMed']['residualConv']['relu']['uniform'][0.1]

GCN_glorot_PubMed = overal_results['PubMed']['GCN']['relu']['glorot'][0.1]
SGC_glorot_PubMed = overal_results['PubMed']['SGC']['relu']['glorot'][0.1]
GAT_glorot_PubMed = overal_results['PubMed']['GAT']['relu']['glorot'][0.1]
Res_glorot_PubMed = overal_results['PubMed']['residualConv']['relu']['glorot'][0.1]

GCN_kaiming_uniform_PubMed = overal_results['PubMed']['GCN']['relu']['kaiming_uniform'][0.1]
SGC_kaiming_uniform_PubMed = overal_results['PubMed']['SGC']['relu']['kaiming_uniform'][0.1]
GAT_kaiming_uniform_PubMed = overal_results['PubMed']['GAT']['relu']['kaiming_uniform'][0.1]
Res_kaiming_uniform_PubMed = overal_results['PubMed']['residualConv']['relu']['kaiming_uniform'][0.1]

fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20,7))
st = fig.suptitle("Initialization Comparison (Relu activation)", fontsize="x-large")
# Plot the distributions and label each Axes
axes[0].plot(GCN_random_Cora, label='GCN-Random', linewidth=2.5)
axes[0].plot(SGC_random_Cora, label='SGC-Random', linewidth=2.5)
axes[0].plot(GAT_random_Cora, label='GAT-Random', linewidth=2.5)
axes[0].plot(Res_random_Cora, label='Res-Random', linewidth=2.5)

axes[0].plot(GCN_uniform_Cora, label='GCN-Uniform', linewidth=2.5)
axes[0].plot(SGC_uniform_Cora, label='SGC-Uniform', linewidth=2.5)
axes[0].plot(GAT_uniform_Cora, label='GAT-Uniform', linewidth=2.5)
axes[0].plot(Res_uniform_Cora, label='Res-Uniform', linewidth=2.5)

axes[0].plot(GCN_glorot_Cora, label='GCN-Golorot', linewidth=2.5)
axes[0].plot(SGC_glorot_Cora, label='SGC-Golorot', linewidth=2.5)
axes[0].plot(GAT_glorot_Cora, label='GAT-Golorot', linewidth=2.5)
axes[0].plot(Res_glorot_Cora, label='Res-Golorot', linewidth=2.5)

axes[0].plot(GCN_kaiming_uniform_Cora, label='GCN-Kaiming', linewidth=2.5)
axes[0].plot(SGC_kaiming_uniform_Cora, label='SGC-Kaiming', linewidth=2.5)
axes[0].plot(GAT_kaiming_uniform_Cora, label='GAT-Kaiming', linewidth=2.5)
axes[0].plot(Res_kaiming_uniform_Cora, label='Res-Kaiming', linewidth=2.5)

axes[0].set_title("Cora Dataset", fontsize = 18)
axes[0].tick_params(axis='x', labelsize = 18)
axes[0].tick_params(axis='y', labelsize = 18)
axes[0].set_ylabel('Accuracy', fontsize = 18)

axes[1].plot(GCN_random_CiteSeer, label='GCN-Random', linewidth=2.5)
axes[1].plot(SGC_random_CiteSeer, label='SGC-Random', linewidth=2.5)
axes[1].plot(GAT_random_CiteSeer, label='GAT-Random', linewidth=2.5)
axes[1].plot(Res_random_CiteSeer, label='Res-Random', linewidth=2.5)

axes[1].plot(GCN_uniform_CiteSeer, label='GCN-Uniform', linewidth=2.5)
axes[1].plot(SGC_uniform_CiteSeer, label='SGC-Uniform', linewidth=2.5)
axes[1].plot(GAT_uniform_CiteSeer, label='GAT-Uniform', linewidth=2.5)
axes[1].plot(Res_uniform_CiteSeer, label='Res-Uniform', linewidth=2.5)

axes[1].plot(GCN_glorot_CiteSeer, label='GCN-Golorot', linewidth=2.5)
axes[1].plot(SGC_glorot_CiteSeer, label='SGC-Golorot', linewidth=2.5)
axes[1].plot(GAT_glorot_CiteSeer, label='GAT-Golorot', linewidth=2.5)
axes[1].plot(Res_glorot_CiteSeer, label='Res-Golorot', linewidth=2.5)

axes[1].plot(GCN_kaiming_uniform_CiteSeer, label='GCN-Kaiming', linewidth=2.5)
axes[1].plot(SGC_kaiming_uniform_CiteSeer, label='SGC-Kaiming', linewidth=2.5)
axes[1].plot(GAT_kaiming_uniform_CiteSeer, label='GAT-Kaiming', linewidth=2.5)
axes[1].plot(Res_kaiming_uniform_CiteSeer, label='Res-Kaiming', linewidth=2.5)

axes[1].set_title("CiteSeer Dataset", fontsize = 18)
axes[1].tick_params(axis='x', labelsize = 18)
axes[1].tick_params(axis='y', labelsize = 18)
axes[1].set_xlabel('Epochs', fontsize = 18)

axes[2].plot(GCN_random_PubMed, label='GCN-Random', linewidth=2.5)
axes[2].plot(SGC_random_PubMed, label='SGC-Random', linewidth=2.5)
axes[2].plot(GAT_random_PubMed, label='GAT-Random', linewidth=2.5)
axes[2].plot(Res_random_PubMed, label='Res-Random', linewidth=2.5)

axes[2].plot(GCN_uniform_PubMed, label='GCN-Uniform', linewidth=2.5)
axes[2].plot(SGC_uniform_PubMed, label='SGC-Uniform', linewidth=2.5)
axes[2].plot(GAT_uniform_PubMed, label='GAT-Uniform', linewidth=2.5)
axes[2].plot(Res_uniform_PubMed, label='Res-Uniform', linewidth=2.5)

axes[2].plot(GCN_glorot_PubMed, label='GCN-Golorot', linewidth=2.5)
axes[2].plot(SGC_glorot_PubMed, label='SGC-Golorot', linewidth=2.5)
axes[2].plot(GAT_glorot_PubMed, label='GAT-Golorot', linewidth=2.5)
axes[2].plot(Res_glorot_PubMed, label='Res-Golorot', linewidth=2.5)

axes[2].plot(GCN_kaiming_uniform_PubMed, label='GCN-Kaiming', linewidth=2.5)
axes[2].plot(SGC_kaiming_uniform_PubMed, label='SGC-Kaiming', linewidth=2.5)
axes[2].plot(GAT_kaiming_uniform_PubMed, label='GAT-Kaiming', linewidth=2.5)
axes[2].plot(Res_kaiming_uniform_PubMed, label='Res-Kaiming', linewidth=2.5)

axes[2].set_title("PubMed Dataset", fontsize = 18)
axes[2].tick_params(axis='x', labelsize = 18)
axes[2].tick_params(axis='y', labelsize = 18)

# Add a legend to each Axes with default values
for ax in axes:
    ax.legend()
plt.tight_layout()
plt.savefig('AllInitialization.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### DropOut Analysis

# %%
one_Cora = overal_results['Cora']['GAT']['relu'][None][0.1]
three_Cora = overal_results['Cora']['GAT']['relu'][None][0.3]
five_Cora = overal_results['Cora']['GAT']['relu'][None][0.5]
seven_Cora = overal_results['Cora']['GAT']['relu'][None][0.7]
nine_Cora = overal_results['Cora']['GAT']['relu'][None][0.9]

one_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.1]
three_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.3]
five_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.5]
seven_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.7]
nine_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.9]

one_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.1]
three_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.3]
five_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.5]
seven_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.7]
nine_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.9]

fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20,7))
st = fig.suptitle("Dropout Comparison  (GAT Layer, relu activation, random initialization)", fontsize="x-large")
# Plot the distributions and label each Axes
axes[0].plot(one_Cora, label='10%',linewidth=3)
axes[0].plot(three_Cora, label='30%',linestyle = 'dashed',linewidth=3)
axes[0].plot(five_Cora, label='50%',linestyle = '-.',linewidth=3)
axes[0].plot(seven_Cora, label='70%',linestyle = 'dotted',linewidth=3)
axes[0].plot(nine_Cora, label='90%',linestyle = ':',linewidth=3)
axes[0].set_title("Cora Dataset", fontsize = 18)
axes[0].set_ylim([0.1, 0.85])
axes[0].tick_params(axis='x', labelsize = 18)
axes[0].tick_params(axis='y', labelsize = 18)
axes[0].set_ylabel('Accuracy', fontsize = 18)

axes[1].plot(one_CiteSeer, label='10%',linewidth=3)
axes[1].plot(three_CiteSeer, label='30%',linestyle = 'dashed',linewidth=3)
axes[1].plot(five_CiteSeer, label='50%',linestyle = '-.',linewidth=3)
axes[1].plot(seven_CiteSeer, label='70%',linestyle = 'dotted',linewidth=3)
axes[1].plot(nine_CiteSeer, label='90%',linestyle = ':',linewidth=3)
axes[1].set_title("CiteSeer Dataset", fontsize = 18)
axes[1].set_ylim([0.1, 0.85])
axes[1].tick_params(axis='x', labelsize = 18)
axes[1].tick_params(axis='y', labelsize = 18)
axes[1].set_xlabel('Epochs', fontsize = 18)

axes[2].plot(one_PubMed, label='10%',linewidth=3)
axes[2].plot(three_PubMed, label='30%',linestyle = 'dashed',linewidth=3)
axes[2].plot(five_PubMed, label='50%',linestyle = '-.',linewidth=3)
axes[2].plot(seven_PubMed, label='70%',linestyle = 'dotted',linewidth=3)
axes[2].plot(nine_PubMed, label='90%',linestyle = ':',linewidth=3)
axes[2].set_title("PubMed Dataset", fontsize = 18)
axes[2].set_ylim([0.1, 0.85])
axes[2].tick_params(axis='x', labelsize = 18)
axes[2].tick_params(axis='y', labelsize = 18)

# Add a legend to each Axes with default values
for ax in axes:
    ax.legend(loc="lower right")
plt.tight_layout()
#plt.savefig('Dropout.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
overal_results['Cora'].keys()
# Out:
# dict_keys(['SGC', 'GCN', 'GAT', 'residualConv'])

# %%
one_Cora = overal_results['Cora']['residualConv']['relu'][None][0.1]
three_Cora = overal_results['Cora']['residualConv']['relu'][None][0.3]
five_Cora = overal_results['Cora']['residualConv']['relu'][None][0.5]
seven_Cora = overal_results['Cora']['residualConv']['relu'][None][0.7]
nine_Cora = overal_results['Cora']['residualConv']['relu'][None][0.9]

one_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.1]
three_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.3]
five_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.5]
seven_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.7]
nine_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.9]

one_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.1]
three_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.3]
five_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.5]
seven_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.7]
nine_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.9]

fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20,7))
st = fig.suptitle("Dropout Comparison  (residualConv Layer, relu activation, random initialization)", fontsize="x-large")
# Plot the distributions and label each Axes
axes[0].plot(one_Cora, label='10%', linewidth=3)
axes[0].plot(three_Cora, label='30%',linestyle = 'dashed', linewidth=3)
axes[0].plot(five_Cora, label='50%',linestyle = '-.', linewidth=3)
axes[0].plot(seven_Cora, label='70%',linestyle = 'dotted', linewidth=3)
axes[0].plot(nine_Cora, label='90%',linestyle = ':', linewidth=3)
axes[0].set_title("Cora Dataset", fontsize = 18)
axes[0].tick_params(axis='x', labelsize = 18)
axes[0].tick_params(axis='y', labelsize = 18)
axes[0].set_ylabel('Accuracy', fontsize = 18)

axes[1].plot(one_CiteSeer, label='10%', linewidth=3)
axes[1].plot(three_CiteSeer, label='30%',linestyle = 'dashed', linewidth=3)
axes[1].plot(five_CiteSeer, label='50%',linestyle = '-.', linewidth=3)
axes[1].plot(seven_CiteSeer, label='70%',linestyle = 'dotted', linewidth=3)
axes[1].plot(nine_CiteSeer, label='90%',linestyle = ':', linewidth=3)
axes[1].set_title("CiteSeer Dataset", fontsize = 18)
axes[1].tick_params(axis='x', labelsize = 18)
axes[1].tick_params(axis='y', labelsize = 18)
axes[1].set_xlabel('Epochs', fontsize = 18)

axes[2].plot(one_PubMed, label='10%', linewidth=3)
axes[2].plot(three_PubMed, label='30%',linestyle = 'dashed', linewidth=3)
axes[2].plot(five_PubMed, label='50%',linestyle = '-.', linewidth=3)
axes[2].plot(seven_PubMed, label='70%',linestyle = 'dotted', linewidth=3)
axes[2].plot(nine_PubMed, label='90%',linestyle = ':', linewidth=3)
axes[2].set_title("PubMed Dataset", fontsize = 18)
axes[2].tick_params(axis='x', labelsize = 18)
axes[2].tick_params(axis='y', labelsize = 18)

# Add a legend to each Axes with default values
for ax in axes:
    ax.legend()
plt.tight_layout()
plt.savefig('AllDropout2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
GCN_one_Cora = overal_results['Cora']['GCN']['relu'][None][0.1]
SGC_one_Cora = overal_results['Cora']['SGC']['relu'][None][0.1]
GAT_one_Cora = overal_results['Cora']['GAT']['relu'][None][0.1]
Res_one_Cora = overal_results['Cora']['residualConv']['relu'][None][0.1]

GCN_three_Cora = overal_results['Cora']['GCN']['relu'][None][0.3]
SGC_three_Cora = overal_results['Cora']['SGC']['relu'][None][0.3]
GAT_three_Cora = overal_results['Cora']['GAT']['relu'][None][0.3]
Res_three_Cora = overal_results['Cora']['residualConv']['relu'][None][0.3]

GCN_five_Cora = overal_results['Cora']['GCN']['relu'][None][0.5]
SGC_five_Cora = overal_results['Cora']['SGC']['relu'][None][0.5]
GAT_five_Cora = overal_results['Cora']['GAT']['relu'][None][0.5]
Res_five_Cora = overal_results['Cora']['residualConv']['relu'][None][0.5]

GCN_seven_Cora = overal_results['Cora']['GCN']['relu'][None][0.7]
SGC_seven_Cora = overal_results['Cora']['SGC']['relu'][None][0.7]
GAT_seven_Cora = overal_results['Cora']['GAT']['relu'][None][0.7]
Res_seven_Cora = overal_results['Cora']['residualConv']['relu'][None][0.7]

GCN_nine_Cora = overal_results['Cora']['GCN']['relu'][None][0.9]
SGC_nine_Cora = overal_results['Cora']['SGC']['relu'][None][0.9]
GAT_nine_Cora = overal_results['Cora']['GAT']['relu'][None][0.9]
Res_nine_Cora = overal_results['Cora']['residualConv']['relu'][None][0.9]

GCN_one_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.1]
SGC_one_CiteSeer = overal_results['CiteSeer']['SGC']['relu'][None][0.1]
GAT_one_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.1]
Res_one_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.1]

GCN_three_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.3]
SGC_three_CiteSeer = overal_results['CiteSeer']['SGC']['relu'][None][0.3]
GAT_three_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.3]
Res_three_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.3]

GCN_five_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.5]
SGC_five_CiteSeer = overal_results['CiteSeer']['SGC']['relu'][None][0.5]
GAT_five_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.5]
Res_five_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.5]

GCN_seven_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.7]
SGC_seven_CiteSeer = overal_results['CiteSeer']['SGC']['relu'][None][0.7]
GAT_seven_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.7]
Res_seven_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.7]

GCN_nine_CiteSeer = overal_results['CiteSeer']['GCN']['relu'][None][0.9]
SGC_nine_CiteSeer = overal_results['CiteSeer']['SGC']['relu'][None][0.9]
GAT_nine_CiteSeer = overal_results['CiteSeer']['GAT']['relu'][None][0.9]
Res_nine_CiteSeer = overal_results['CiteSeer']['residualConv']['relu'][None][0.9]

GCN_one_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.1]
SGC_one_PubMed = overal_results['PubMed']['SGC']['relu'][None][0.1]
GAT_one_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.1]
Res_one_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.1]

GCN_three_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.3]
SGC_three_PubMed = overal_results['PubMed']['SGC']['relu'][None][0.3]
GAT_three_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.3]
Res_three_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.3]

GCN_five_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.5]
SGC_five_PubMed = overal_results['PubMed']['SGC']['relu'][None][0.5]
GAT_five_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.5]
Res_five_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.5]

GCN_seven_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.7]
SGC_seven_PubMed = overal_results['PubMed']['SGC']['relu'][None][0.7]
GAT_seven_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.7]
Res_seven_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.7]

GCN_nine_PubMed = overal_results['PubMed']['GCN']['relu'][None][0.9]
SGC_nine_PubMed = overal_results['PubMed']['SGC']['relu'][None][0.9]
GAT_nine_PubMed = overal_results['PubMed']['GAT']['relu'][None][0.9]
Res_nine_PubMed = overal_results['PubMed']['residualConv']['relu'][None][0.9]

fig, axes = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20,7))
st = fig.suptitle("Dropout Comparison", fontsize="x-large")
# Plot the distributions and label each Axes
axes[0].plot(GCN_one_Cora, label='GCN_10%', linewidth=2.5)
axes[0].plot(SGC_one_Cora, label='SGC-10%', linewidth=2.5)
axes[0].plot(GAT_one_Cora, label='GAT-10%', linewidth=2.5)
axes[0].plot(Res_one_Cora, label='Res-10%', linewidth=2.5)

axes[0].plot(GCN_three_Cora, label='GCN-30%', linewidth=2.5)
axes[0].plot(SGC_three_Cora, label='SGC-30%', linewidth=2.5)
axes[0].plot(GAT_three_Cora, label='GAT-30%', linewidth=2.5)
axes[0].plot(Res_three_Cora, label='Res-30%', linewidth=2.5)

axes[0].plot(GCN_five_Cora, label='GCN_50%', linewidth=2.5)
axes[0].plot(SGC_five_Cora, label='SGC_50%', linewidth=2.5)
axes[0].plot(GAT_five_Cora, label='GAT_50%', linewidth=2.5)
axes[0].plot(Res_five_Cora, label='Res-50%', linewidth=2.5)

axes[0].plot(GCN_seven_Cora, label='GCN-70%', linewidth=2.5)
axes[0].plot(SGC_seven_Cora, label='SGC-70%', linewidth=2.5)
axes[0].plot(GAT_seven_Cora, label='GAT-70%', linewidth=2.5)
axes[0].plot(Res_seven_Cora, label='Res-70%', linewidth=2.5)

axes[0].plot(GCN_nine_Cora, label='GCN-90%', linewidth=2.5)
axes[0].plot(SGC_nine_Cora, label='SGC-90%', linewidth=2.5)
axes[0].plot(GAT_nine_Cora, label='GAT-90%', linewidth=2.5)
axes[0].plot(Res_nine_Cora, label='Res-90%', linewidth=2.5)

axes[0].set_title("Cora Dataset", fontsize=18)
axes[0].tick_params(axis='x', labelsize = 18)
axes[0].tick_params(axis='y', labelsize = 18)
axes[0].set_ylabel('Accuracy', fontsize = 18)

axes[1].plot(GCN_one_CiteSeer, label='GCN-10%', linewidth=2.5)
axes[1].plot(SGC_one_CiteSeer, label='SGC-10%', linewidth=2.5)
axes[1].plot(GAT_one_CiteSeer, label='GAT-10%', linewidth=2.5)
axes[1].plot(Res_one_CiteSeer, label='Res-10%', linewidth=2.5)

axes[1].plot(GCN_three_CiteSeer, label='GCN-30%', linewidth=2.5)
axes[1].plot(SGC_three_CiteSeer, label='SGC-30%', linewidth=2.5)
axes[1].plot(GAT_three_CiteSeer, label='GAT-30%', linewidth=2.5)
axes[1].plot(Res_three_CiteSeer, label='Res-30%', linewidth=2.5)

axes[1].plot(GCN_five_CiteSeer, label='GCN-50%', linewidth=2.5)
axes[1].plot(SGC_five_CiteSeer, label='SGC-50%', linewidth=2.5)
axes[1].plot(GAT_five_CiteSeer, label='GAT-50%', linewidth=2.5)
axes[1].plot(Res_five_CiteSeer, label='Res-50%', linewidth=2.5)

axes[1].plot(GCN_seven_CiteSeer, label='GCN-0%', linewidth=2.5)
axes[1].plot(SGC_seven_CiteSeer, label='SGC-70%', linewidth=2.5)
axes[1].plot(GAT_seven_CiteSeer, label='GAT-70%', linewidth=2.5)
axes[1].plot(Res_seven_CiteSeer, label='Res-70%', linewidth=2.5)

axes[1].plot(GCN_nine_CiteSeer, label='GCN-90%', linewidth=2.5)
axes[1].plot(SGC_nine_CiteSeer, label='SGC-90%', linewidth=2.5)
axes[1].plot(GAT_nine_CiteSeer, label='GAT-90%', linewidth=2.5)
axes[1].plot(Res_nine_CiteSeer, label='Res-90%', linewidth=2.5)

axes[1].set_title("CiteSeer Dataset", fontsize=18)
axes[1].tick_params(axis='x', labelsize = 18)
axes[1].tick_params(axis='y', labelsize = 18)
axes[1].set_xlabel('Epochs', fontsize = 18)

axes[2].plot(GCN_one_PubMed, label='GCN-10%', linewidth=2.5)
axes[2].plot(SGC_one_PubMed, label='SGC-10%', linewidth=2.5)
axes[2].plot(GAT_one_PubMed, label='GAT-10%', linewidth=2.5)
axes[2].plot(Res_one_PubMed, label='Res-10%', linewidth=2.5)

axes[2].plot(GCN_three_PubMed, label='GCN-30%', linewidth=2.5)
axes[2].plot(SGC_three_PubMed, label='SGC-30%', linewidth=2.5)
axes[2].plot(GAT_three_PubMed, label='GAT-30%', linewidth=2.5)
axes[2].plot(Res_three_PubMed, label='Res-30%', linewidth=2.5)

axes[2].plot(GCN_five_PubMed, label='GCN-50%', linewidth=2.5)
axes[2].plot(SGC_five_PubMed, label='SGC-50%', linewidth=2.5)
axes[2].plot(GAT_five_PubMed, label='GAT-50%', linewidth=2.5)
axes[2].plot(Res_five_PubMed, label='Res-50%', linewidth=2.5)

axes[2].plot(GCN_seven_PubMed, label='GCN-70%', linewidth=2.5)
axes[2].plot(SGC_seven_PubMed, label='SGC-70%', linewidth=2.5)
axes[2].plot(GAT_seven_PubMed, label='GAT-70%', linewidth=2.5)
axes[2].plot(Res_seven_PubMed, label='Res-70%', linewidth=2.5)

axes[2].plot(GCN_nine_PubMed, label='GCN-90%', linewidth=2.5)
axes[2].plot(SGC_nine_PubMed, label='SGC-90%', linewidth=2.5)
axes[2].plot(GAT_nine_PubMed, label='GAT-90%', linewidth=2.5)
axes[2].plot(Res_nine_PubMed, label='Res-90%', linewidth=2.5)

axes[2].set_title("PubMed Dataset", fontsize=18)
axes[2].tick_params(axis='x', labelsize = 18)
axes[2].tick_params(axis='y', labelsize = 18)

# Add a legend to each Axes with default values
for ax in axes:
    ax.legend()
plt.tight_layout()
plt.savefig('AllDropout.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Ratio of node to edge is quite important in the model robustness when dropout rate increase
#
# Changing optimization mehtod from Adam to SGD didn't make any difference

# %% [markdown]
# ### Summary Table

# %%
table_size = len(overal_results.keys()) * len(overal_results['Cora'].keys()) * len(overal_results['Cora']['GCN'].keys()) * len(overal_results['Cora']['GCN']['relu'].keys()) * len(overal_results['Cora']['GCN']['relu'][None].keys())

summary_table = pd.DataFrame(columns=['data', 'layer', 'activationFun','initialization','dropOutRate','mean_acc'], index=range(table_size))
counter = 0
for dtsts in overal_results.keys():
    for lyrs in overal_results[dtsts].keys():
        for act_nm in overal_results[dtsts][lyrs].keys():
            for init_mt in overal_results[dtsts][lyrs][act_nm].keys():
                for drp_rt in overal_results[dtsts][lyrs][act_nm][init_mt].keys():
                    summary_table.iloc[counter,summary_table.columns.get_loc('data')] = dtsts
                    summary_table.iloc[counter,summary_table.columns.get_loc('layer')] = lyrs
                    summary_table.iloc[counter,summary_table.columns.get_loc('activationFun')] = act_nm
                    summary_table.iloc[counter,summary_table.columns.get_loc('initialization')] = init_mt
                    summary_table.iloc[counter,summary_table.columns.get_loc('dropOutRate')] = drp_rt
                    summary_table.iloc[counter,summary_table.columns.get_loc('mean_acc')] = np.mean(overal_results[dtsts][lyrs][act_nm][init_mt][drp_rt])
                    counter += 1

# %%
summary_table.head()
# Out:
#    data layer activationFun initialization dropOutRate  mean_acc
# 0  Cora   SGC          relu         glorot         0.1  0.760258
# 1  Cora   SGC          relu         glorot         0.3  0.696142
# 2  Cora   SGC          relu         glorot         0.5  0.664401
# 3  Cora   SGC          relu         glorot         0.7  0.502207
# 4  Cora   SGC          relu         glorot         0.9   0.32673

# %%
summary_table.to_excel('summary_table.xlsx', index = False)

# %% [markdown]
# ### Boxplot

# %% [markdown]
# ### Plot From DRL Mangul book

# %%
ddqn_max_t, ddqn_max_r, ddqn_max_s, ddqn_max_sec, ddqn_max_rt = np.max(ddqn_results, axis=0).T
ddqn_min_t, ddqn_min_r, ddqn_min_s, ddqn_min_sec, ddqn_min_rt = np.min(ddqn_results, axis=0).T
ddqn_mean_t, ddqn_mean_r, ddqn_mean_s, ddqn_mean_sec, ddqn_mean_rt = np.mean(ddqn_results, axis=0).T
ddqn_x = np.arange(np.max((len(ddqn_mean_s), len(dqn_mean_s))))

# %%
fig, axs = plt.subplots(5, 1, figsize=(15,30), sharey=False, sharex=True)

# DQN
axs[0].plot(dqn_max_r, 'b', linewidth=1)
axs[0].plot(dqn_min_r, 'b', linewidth=1)
axs[0].plot(dqn_mean_r, 'b--', label='DQN', linewidth=2)
axs[0].fill_between(dqn_x, dqn_min_r, dqn_max_r, facecolor='b', alpha=0.3)

axs[1].plot(dqn_max_s, 'b', linewidth=1)
axs[1].plot(dqn_min_s, 'b', linewidth=1)
axs[1].plot(dqn_mean_s, 'b--', label='DQN', linewidth=2)
axs[1].fill_between(dqn_x, dqn_min_s, dqn_max_s, facecolor='b', alpha=0.3)

axs[2].plot(dqn_max_t, 'b', linewidth=1)
axs[2].plot(dqn_min_t, 'b', linewidth=1)
axs[2].plot(dqn_mean_t, 'b--', label='DQN', linewidth=2)
axs[2].fill_between(dqn_x, dqn_min_t, dqn_max_t, facecolor='b', alpha=0.3)

axs[3].plot(dqn_max_sec, 'b', linewidth=1)
axs[3].plot(dqn_min_sec, 'b', linewidth=1)
axs[3].plot(dqn_mean_sec, 'b--', label='DQN', linewidth=2)
axs[3].fill_between(dqn_x, dqn_min_sec, dqn_max_sec, facecolor='b', alpha=0.3)

axs[4].plot(dqn_max_rt, 'b', linewidth=1)
axs[4].plot(dqn_min_rt, 'b', linewidth=1)
axs[4].plot(dqn_mean_rt, 'b--', label='DQN', linewidth=2)
axs[4].fill_between(dqn_x, dqn_min_rt, dqn_max_rt, facecolor='b', alpha=0.3)

# DDQN
axs[0].plot(ddqn_max_r, 'g', linewidth=1)
axs[0].plot(ddqn_min_r, 'g', linewidth=1)
axs[0].plot(ddqn_mean_r, 'g-.', label='DDQN', linewidth=2)
axs[0].fill_between(ddqn_x, ddqn_min_r, ddqn_max_r, facecolor='g', alpha=0.3)

axs[1].plot(ddqn_max_s, 'g', linewidth=1)
axs[1].plot(ddqn_min_s, 'g', linewidth=1)
axs[1].plot(ddqn_mean_s, 'g-.', label='DDQN', linewidth=2)
axs[1].fill_between(ddqn_x, ddqn_min_s, ddqn_max_s, facecolor='g', alpha=0.3)

axs[2].plot(ddqn_max_t, 'g', linewidth=1)
axs[2].plot(ddqn_min_t, 'g', linewidth=1)
axs[2].plot(ddqn_mean_t, 'g-.', label='DDQN', linewidth=2)
axs[2].fill_between(ddqn_x, ddqn_min_t, ddqn_max_t, facecolor='g', alpha=0.3)

axs[3].plot(ddqn_max_sec, 'g', linewidth=1)
axs[3].plot(ddqn_min_sec, 'g', linewidth=1)
axs[3].plot(ddqn_mean_sec, 'g-.', label='DDQN', linewidth=2)
axs[3].fill_between(ddqn_x, ddqn_min_sec, ddqn_max_sec, facecolor='g', alpha=0.3)

axs[4].plot(ddqn_max_rt, 'g', linewidth=1)
axs[4].plot(ddqn_min_rt, 'g', linewidth=1)
axs[4].plot(ddqn_mean_rt, 'g-.', label='DDQN', linewidth=2)
axs[4].fill_between(ddqn_x, ddqn_min_rt, ddqn_max_rt, facecolor='g', alpha=0.3)

# ALL
axs[0].set_title('Moving Avg Reward (Training)')
axs[1].set_title('Moving Avg Reward (Evaluation)')
axs[2].set_title('Total Steps')
axs[3].set_title('Training Time')
axs[4].set_title('Wall-clock Time')
plt.xlabel('Episodes')
axs[0].legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Draw this boxplot like chart to compare the results

# %%
parts = plt.violinplot((x, xd, a, ad), 
                       vert=False, showmeans=False, showmedians=False, showextrema=False)

colors = ['red','green','yellow','blue']
for i, pc in enumerate(parts['bodies']):
    pc.set_facecolor(colors[i])
    pc.set_edgecolor(colors[i])
    pc.set_alpha(0.5)

plt.yticks(range(1,5), ["cart position", "cart velocity", "pole angle", "pole velocity"])
plt.yticks(rotation=45)
plt.title('Range of state-variable values for ' + str(
    ddqn_agents[best_ddqn_agent_key].__class__.__name__))

plt.show()
